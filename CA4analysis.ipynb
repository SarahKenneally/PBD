# %%
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import datetime as dt

# %%
##importing Librarys for use and then importing CSV

# %%
changes=pd.read_csv("/Users/sarahkenneally/Downloads/CA4changesSarah.csv")

# %%
changes['author'] = changes.author.astype(str)

# %%
changes.head()
# Out:
#    revision                                           author        date  \
# 0  r1551925                                           Thomas  27/11/2015
# 1  r1551575                                           Thomas  27/11/2015
# 2  r1551569                                          Vincent  27/11/2015
# 3  r1551558                                           Thomas  27/11/2015
# 4  r1551504  /OU=Domain Control Validated/CN=svn.company.net  27/11/2015
#
#        time  number_of_lines  \
# 0  16:57:44                1
# 1  09:46:32                1
# 2  09:38:09                1
# 3  09:13:26                1
# 4  07:05:41                1
#
#                                              comment Unnamed: 6 Unnamed: 7  \
# 0                 Renamed folder to the correct name        NaN        NaN
# 1  Removed unused webview.plan.management and web...        NaN        NaN
# 2                                 enable all clients        NaN        NaN
# ...

# %%
pd.isnull(changes)
# Out:
#      revision  author   date   time  number_of_lines  comment  Unnamed: 6  \
# 0       False   False  False  False            False    False        True
# 1       False   False  False  False            False    False        True
# 2       False   False  False  False            False    False        True
# 3       False   False  False  False            False    False        True
# 4       False   False  False  False            False    False        True
# 5       False   False  False  False            False    False        True
# 6       False   False  False  False            False    False        True
# 7       False   False  False  False            False    False        True
# 8       False   False  False  False            False    False        True
# 9       False   False  False  False            False    False        True
# 10      False   False  False  False            False    False        True
# 11      False   False  False  False            False    False        True
# ...

# %%
##lots of null value columns

# %%
changesnew = changes.dropna(axis=1)

# %% [raw]
# ##dropped null value columns and kept only good data

# %%
changesnew.shape
# Out:
# (422, 6)

# %%
changesnew.head()
# Out:
#    revision                                           author        date  \
# 0  r1551925                                           Thomas  27/11/2015
# 1  r1551575                                           Thomas  27/11/2015
# 2  r1551569                                          Vincent  27/11/2015
# 3  r1551558                                           Thomas  27/11/2015
# 4  r1551504  /OU=Domain Control Validated/CN=svn.company.net  27/11/2015
#
#        time  number_of_lines  \
# 0  16:57:44                1
# 1  09:46:32                1
# 2  09:38:09                1
# 3  09:13:26                1
# 4  07:05:41                1
#
#                                              comment
# 0                 Renamed folder to the correct name
# 1  Removed unused webview.plan.management and web...
# 2                                 enable all clients
# 3                           Chnaged jira url to htps
# 4  [gradle-release] prepare for next development ...

# %%
print(changesnew.describe())
# Out:
#        number_of_lines
# count       422.000000
# mean          1.315166
# std           0.845672
# min           1.000000
# 25%           1.000000
# 50%           1.000000
# 75%           1.000000
# max           7.000000

# %%
changesnew.groupby('author').count()
# Out:
#                                                  revision  date  time  \
# author
# /OU=Domain Control Validated/CN=svn.company.net        24    24    24
# Alan                                                    5     5     5
# Dave                                                    2     2     2
# Freddie                                                 7     7     7
# Jimmy                                                 152   152   152
# Nicky                                                   5     5     5
# Thomas                                                191   191   191
# Vincent                                                26    26    26
# ajon0002                                                9     9     9
# murari.krishnan                                         1     1     1
#
#                                                  number_of_lines  comment
# author
# /OU=Domain Control Validated/CN=svn.company.net               24       24
# ...

# %%
##change long user name to unknown user

# %%
changesnew.author=changesnew.author.replace({'/OU=Domain Control Validated/CN=svn.company.net':'Unknown User'})

# %%
AuthorCount = changesnew.groupby('author').count()

# %%
changesnew.groupby(['author', 'date'])['revision'].count()
# Out:
# author           date
# Alan             13/07/2015     1
#                  15/07/2015     1
#                  16/07/2015     3
# Dave             12/11/2015     1
#                  23/07/2015     1
# Freddie          03/09/2015     1
#                  07/09/2015     2
#                  19/11/2015     1
#                  26/08/2015     2
#                  28/08/2015     1
# Jimmy            01/10/2015     2
#                  03/11/2015     3
#                  04/08/2015     8
#                  05/08/2015     2
#                  07/08/2015     2
#                  09/09/2015     3
#                  09/10/2015     3
#                  10/08/2015     4
#                  10/09/2015     2
#                  12/08/2015     7
#                  12/11/2015     8
#                  13/07/2015     4
#                  13/08/2015     5
#                  14/07/2015     7
#                  14/08/2015     4
#                  14/10/2015     4
#                  15/07/2015    10
# ...

# %%
Authorcount = changesnew.author.value_counts()
print(Authorcount)
# Out:
# Thomas             191
# Jimmy              152
# Vincent             26
# Unknown User        24
# ajon0002             9
# Freddie              7
# Alan                 5
# Nicky                5
# Dave                 2
# murari.krishnan      1
# Name: author, dtype: int64

# %%
Author_Count.plot(kind='bar')
plt.title("Revisons per Author")
plt.xlabel("Author")
plt.ylabel("Number of Revisons")
# Out:
# Text(0, 0.5, 'Number of Revisons')

# %%
Dayscount.plot(kind='pie')
plt.title("Revisons per Day")
plt.xlabel("Day")
plt.ylabel("Number of Revisons")
# Out:
# Text(0, 0.5, 'Number of Revisons')

# %%
## find date with highest amoutn of revisons

# %%
Datecount = changesnew.groupby(['date'])['number_of_lines'].sum()
print(Datecount)
# Out:
# date
# 01/10/2015     3
# 02/10/2015     6
# 02/11/2015    26
# 03/09/2015     3
# 03/11/2015     6
# 04/08/2015    19
# 04/09/2015     6
# 04/11/2015    15
# 05/08/2015     5
# 05/11/2015     5
# 06/08/2015     2
# 06/10/2015    11
# 07/08/2015     2
# 07/09/2015     4
# 07/10/2015     8
# 08/09/2015     5
# 08/10/2015     4
# 09/09/2015    10
# 09/10/2015    12
# 10/08/2015     4
# 10/09/2015     3
# 12/08/2015     8
# 12/11/2015    19
# 13/07/2015    14
# 13/08/2015    10
# 13/10/2015     4
# 14/07/2015     7
# 14/08/2015     4
# 14/10/2015     4
# 15/07/2015    13
#               ..
# 21/07/2015     6
# 21/08/2015     4
# 22/07/2015     3
# 22/09/2015     1
# 22/10/2015    11
# 23/07/2015    10
# 23/10/2015     9
# 23/11/2015    11
# 24/07/2015    10
# 24/08/2015     2
# 24/11/2015    13
# 25/08/2015     7
# 25/09/2015     3
# 25/11/2015     7
# 26/08/2015     5
# 26/11/2015    30
# 27/07/2015     5
# 27/08/2015     2
# 27/10/2015     7
# 27/11/2015     7
# 28/07/2015     2
# ...

# %%
## find first and last date changes were recorded for

# %%
changesnew['date'].min()
# Out:
# '01/10/2015'

# %%
changesnew['date'].max()
# Out:
# '31/07/2015'

# %%
## confirm 30 is the highest number of revisions confirmed in one day and find out other statistical info onrevisons per dates

# %%
print(Datecount.describe())
# Out:
# count    76.000000
# mean      7.302632
# std       5.645103
# min       1.000000
# 25%       3.000000
# 50%       6.000000
# 75%      10.000000
# max      30.000000
# Name: number_of_lines, dtype: float64
